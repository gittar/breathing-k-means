# %% [markdown]
# # Breathing k-means
# ## High-dimensional datasets - compact code

# %%
import os
import sys
sys.path.append(os.path.join("..","bkmeans"))
sys.path.append(os.path.join("..","misc"))
from runfunctions import solve_problem
from dataset import DataSet

# %% [markdown]
# ### Dataset "Norm25-new"

# %%
D = DataSet.from_csv_file("../data/Norm25-new.zip")
solve_problem(D, k=50,ticks=0,showdim=0,repeat=1)
# Out:
# k-means++:               SSE=141741.750                 t=  0.78s
# breathing k-means:       SSE=140350.564 (0.98% lower)   t=  2.84s (+265.29%)

# %% [markdown]
# ### Dataset "Cloud"

# %%
D = DataSet.from_csv_file("../data/Cloud.zip")
solve_problem(D, k=50,ticks=0,figsize=(20,10),showdim=(1,2),square=0,repeat=1)
# Out:
# k-means++:               SSE=1084155.849                 t=  0.36s
# breathing k-means:       SSE=1059017.829 (2.32% lower)   t=  0.56s (+54.59%)

# %% [markdown]
# ### Dataset "Intrusion"

# %%
D = DataSet.from_csv_file("../data/Intrusion.zip")
solve_problem(D, k=50,ticks=0,showdim=25)
# Out:
# k-means++:               SSE=205585890697.449                 t= 43.94s
# breathing k-means:       SSE=194595035905.329 (5.35% lower)   t=119.10s (+171.05%)

# %% [markdown]
# ### Dataset "Spam"
# (in the paper the displayed data was cut off in the vertical direction to save space)

# %%
D = DataSet.from_csv_file("../data/Spam.zip")
solve_problem(D, k=50,ticks=0,showdim=(11,18),figsize=(21,15),repeat=1)
# Out:
# k-means++:               SSE=5920512.400                 t=  4.43s
# breathing k-means:       SSE=5783507.007 (2.31% lower)   t=  7.63s (+72.42%)
