# %% [markdown]
# # Breathing k-means
# ## High-dimensional datasets

# %%
import os
import sys
sys.path.append(os.path.join("..","bkmeans"))
sys.path.append(os.path.join("..","misc"))

from runfunctions import solve_problem
from dataset import DataSet

# %% [markdown]
# ## Symbols used
#
# * $\phi$ : Summed Square Error (i.e., SSE)
#
# * $\Delta\phi = 1 - \phi_{bkm}/\phi_{km++}$ (error improvement over `k-means++`)
#
# * $t$ : CPU time
#
# * $\Delta t = 1 - t_{bkm}/t_{km++}$ (CPU time improvement over `k-means++`)

# %%
# optional extra parameters for the simulation function
args={}

# uncomment the following line for repeatings each experiments `repeat` times
# args={"repeat":10, "dotext":0}

# set "dotext":1 for seeing again every single result

# %% [markdown]
# ### Dataset "Norm25-new"

# %%
D = DataSet.from_csv_file("../data/Norm25-new.zip",name="Norm25-new")
solve_problem(D, k=100,ticks=0,showdim=0, **args)
# Out:
# <style  type="text/css" >
#     #T_0014e_ th {
#           border-left: 1px solid white;
#     }    #T_0014e_ td {
#           border-left: 1px solid #aaa;
#     }    #T_0014e_ td:nth-child(1) {
#           border-left: 0px solid red;
#     }    #T_0014e_ .col6.row0 {
#           background-color: #afa;
#     }    #T_0014e_ .col9.row0 {
#           background-color: #afa;
#     }    #T_0014e_ th {
#           background-color: #ddd;
#     }#T_0014e_row0_col0,#T_0014e_row0_col1,#T_0014e_row0_col2,#T_0014e_row0_col3,#T_0014e_row0_col4,#T_0014e_row0_col5,#T_0014e_row0_col6,#T_0014e_row0_col7,#T_0014e_row0_col8,#T_0014e_row0_col9,#T_0014e_row0_col10{
#             background-color:  #eee;
#             color:  black;
#             border-color:  white;
#         }</style><table id="T_0014e_" ><thead>    <tr>        <th class="col_heading level0 col0" >data set</th>        <th class="col_heading level0 col1" >n</th>        <th class="col_heading level0 col2" >d</th>        <th class="col_heading level0 col3" >k</th>        <th class="col_heading level0 col4" >$\phi(\mbox{km}$++)</th>        <th class="col_heading level0 col5" >$\phi(\mbox{bkm})$</th>        <th class="col_heading level0 col6" >$\Delta\phi$</th>        <th class="col_heading level0 col7" >$t_{\textrm{km++}}$</th>        <th class="col_heading level0 col8" >$t_{\textrm{bkm}}$</th>        <th class="col_heading level0 col9" >$\Delta t$</th>        <th class="col_heading level0 col10" >runs</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_0014e_row0_col0" class="data row0 col0" >Norm25-new</td>
#                         <td id="T_0014e_row0_col1" class="data row0 col1" >10000</td>
#                         <td id="T_0014e_row0_col2" class="data row0 col2" >15</td>
#                         <td id="T_0014e_row0_col3" class="data row0 col3" >100</td>
#                         <td id="T_0014e_row0_col4" class="data row0 col4" >1.310e+05</td>
#                         <td id="T_0014e_row0_col5" class="data row0 col5" >1.300e+05</td>
#                         <td id="T_0014e_row0_col6" class="data row0 col6" >0.81% (lower SSE)</td>
#                         <td id="T_0014e_row0_col7" class="data row0 col7" >2.39 sec</td>
#                         <td id="T_0014e_row0_col8" class="data row0 col8" >1.67 sec</td>
#                         <td id="T_0014e_row0_col9" class="data row0 col9" >30.19% (faster)</td>
#                         <td id="T_0014e_row0_col10" class="data row0 col10" >1</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ### Dataset "Cloud"

# %%
D = DataSet.from_csv_file("../data/Cloud.zip",name="Cloud")
solve_problem(D, k=100,ticks=0,figsize=(20,10),showdim=(1,2), **args)
# Out:
# <style  type="text/css" >
#     #T_78c61_ th {
#           border-left: 1px solid white;
#     }    #T_78c61_ td {
#           border-left: 1px solid #aaa;
#     }    #T_78c61_ td:nth-child(1) {
#           border-left: 0px solid red;
#     }    #T_78c61_ .col6.row0 {
#           background-color: #afa;
#     }    #T_78c61_ .col9.row0 {
#           background-color: #afa;
#     }    #T_78c61_ th {
#           background-color: #ddd;
#     }#T_78c61_row0_col0,#T_78c61_row0_col1,#T_78c61_row0_col2,#T_78c61_row0_col3,#T_78c61_row0_col4,#T_78c61_row0_col5,#T_78c61_row0_col6,#T_78c61_row0_col7,#T_78c61_row0_col8,#T_78c61_row0_col9,#T_78c61_row0_col10{
#             background-color:  #eee;
#             color:  black;
#             border-color:  white;
#         }</style><table id="T_78c61_" ><thead>    <tr>        <th class="col_heading level0 col0" >data set</th>        <th class="col_heading level0 col1" >n</th>        <th class="col_heading level0 col2" >d</th>        <th class="col_heading level0 col3" >k</th>        <th class="col_heading level0 col4" >$\phi(\mbox{km}$++)</th>        <th class="col_heading level0 col5" >$\phi(\mbox{bkm})$</th>        <th class="col_heading level0 col6" >$\Delta\phi$</th>        <th class="col_heading level0 col7" >$t_{\textrm{km++}}$</th>        <th class="col_heading level0 col8" >$t_{\textrm{bkm}}$</th>        <th class="col_heading level0 col9" >$\Delta t$</th>        <th class="col_heading level0 col10" >runs</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_78c61_row0_col0" class="data row0 col0" >Cloud</td>
#                         <td id="T_78c61_row0_col1" class="data row0 col1" >1024</td>
#                         <td id="T_78c61_row0_col2" class="data row0 col2" >10</td>
#                         <td id="T_78c61_row0_col3" class="data row0 col3" >100</td>
#                         <td id="T_78c61_row0_col4" class="data row0 col4" >6.021e+05</td>
#                         <td id="T_78c61_row0_col5" class="data row0 col5" >5.885e+05</td>
#                         <td id="T_78c61_row0_col6" class="data row0 col6" >2.26% (lower SSE)</td>
#                         <td id="T_78c61_row0_col7" class="data row0 col7" >0.87 sec</td>
#                         <td id="T_78c61_row0_col8" class="data row0 col8" >0.39 sec</td>
#                         <td id="T_78c61_row0_col9" class="data row0 col9" >54.82% (faster)</td>
#                         <td id="T_78c61_row0_col10" class="data row0 col10" >1</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ### Dataset "Intrusion"

# %%
# commented out since this can take over two minutes for one run
if 0:
    D = DataSet.from_csv_file("../data/Intrusion.zip",name="Intrusion")
    solve_problem(D, k=100,ticks=0,showdim=25, **args)
# Out:
# <style  type="text/css" >
#     #T_e3d75_ th {
#           border-left: 1px solid white;
#     }    #T_e3d75_ td {
#           border-left: 1px solid #aaa;
#     }    #T_e3d75_ td:nth-child(1) {
#           border-left: 0px solid red;
#     }    #T_e3d75_ .col6.row0 {
#           background-color: #afa;
#     }    #T_e3d75_ .col9.row0 {
#           background-color: #afa;
#     }    #T_e3d75_ th {
#           background-color: #ddd;
#     }#T_e3d75_row0_col0,#T_e3d75_row0_col1,#T_e3d75_row0_col2,#T_e3d75_row0_col3,#T_e3d75_row0_col4,#T_e3d75_row0_col5,#T_e3d75_row0_col6,#T_e3d75_row0_col7,#T_e3d75_row0_col8,#T_e3d75_row0_col9,#T_e3d75_row0_col10{
#             background-color:  #eee;
#             color:  black;
#             border-color:  white;
#         }</style><table id="T_e3d75_" ><thead>    <tr>        <th class="col_heading level0 col0" >data set</th>        <th class="col_heading level0 col1" >n</th>        <th class="col_heading level0 col2" >d</th>        <th class="col_heading level0 col3" >k</th>        <th class="col_heading level0 col4" >$\phi(\mbox{km}$++)</th>        <th class="col_heading level0 col5" >$\phi(\mbox{bkm})$</th>        <th class="col_heading level0 col6" >$\Delta\phi$</th>        <th class="col_heading level0 col7" >$t_{\textrm{km++}}$</th>        <th class="col_heading level0 col8" >$t_{\textrm{bkm}}$</th>        <th class="col_heading level0 col9" >$\Delta t$</th>        <th class="col_heading level0 col10" >runs</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_e3d75_row0_col0" class="data row0 col0" >Intrusion</td>
#                         <td id="T_e3d75_row0_col1" class="data row0 col1" >494021</td>
#                         <td id="T_e3d75_row0_col2" class="data row0 col2" >35</td>
#                         <td id="T_e3d75_row0_col3" class="data row0 col3" >100</td>
#                         <td id="T_e3d75_row0_col4" class="data row0 col4" >3.864e+10</td>
#                         <td id="T_e3d75_row0_col5" class="data row0 col5" >3.748e+10</td>
#                         <td id="T_e3d75_row0_col6" class="data row0 col6" >2.99% (lower SSE)</td>
#                         <td id="T_e3d75_row0_col7" class="data row0 col7" >86.78 sec</td>
#                         <td id="T_e3d75_row0_col8" class="data row0 col8" >64.74 sec</td>
#                         <td id="T_e3d75_row0_col9" class="data row0 col9" >25.40% (faster)</td>
#                         <td id="T_e3d75_row0_col10" class="data row0 col10" >1</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ### Dataset "Spam"

# %%
D = DataSet.from_csv_file("../data/Spam.zip",name="Spam")
solve_problem(D, k=200,ticks=0,showdim=(11,18),figsize=(21,15), **args)
# Out:
# <style  type="text/css" >
#     #T_fca7b_ th {
#           border-left: 1px solid white;
#     }    #T_fca7b_ td {
#           border-left: 1px solid #aaa;
#     }    #T_fca7b_ td:nth-child(1) {
#           border-left: 0px solid red;
#     }    #T_fca7b_ .col6.row0 {
#           background-color: #afa;
#     }    #T_fca7b_ .col9.row0 {
#           background-color: #afa;
#     }    #T_fca7b_ th {
#           background-color: #ddd;
#     }#T_fca7b_row0_col0,#T_fca7b_row0_col1,#T_fca7b_row0_col2,#T_fca7b_row0_col3,#T_fca7b_row0_col4,#T_fca7b_row0_col5,#T_fca7b_row0_col6,#T_fca7b_row0_col7,#T_fca7b_row0_col8,#T_fca7b_row0_col9,#T_fca7b_row0_col10{
#             background-color:  #eee;
#             color:  black;
#             border-color:  white;
#         }</style><table id="T_fca7b_" ><thead>    <tr>        <th class="col_heading level0 col0" >data set</th>        <th class="col_heading level0 col1" >n</th>        <th class="col_heading level0 col2" >d</th>        <th class="col_heading level0 col3" >k</th>        <th class="col_heading level0 col4" >$\phi(\mbox{km}$++)</th>        <th class="col_heading level0 col5" >$\phi(\mbox{bkm})$</th>        <th class="col_heading level0 col6" >$\Delta\phi$</th>        <th class="col_heading level0 col7" >$t_{\textrm{km++}}$</th>        <th class="col_heading level0 col8" >$t_{\textrm{bkm}}$</th>        <th class="col_heading level0 col9" >$\Delta t$</th>        <th class="col_heading level0 col10" >runs</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_fca7b_row0_col0" class="data row0 col0" >Spam</td>
#                         <td id="T_fca7b_row0_col1" class="data row0 col1" >4601</td>
#                         <td id="T_fca7b_row0_col2" class="data row0 col2" >58</td>
#                         <td id="T_fca7b_row0_col3" class="data row0 col3" >200</td>
#                         <td id="T_fca7b_row0_col4" class="data row0 col4" >6.649e+05</td>
#                         <td id="T_fca7b_row0_col5" class="data row0 col5" >6.410e+05</td>
#                         <td id="T_fca7b_row0_col6" class="data row0 col6" >3.59% (lower SSE)</td>
#                         <td id="T_fca7b_row0_col7" class="data row0 col7" >4.12 sec</td>
#                         <td id="T_fca7b_row0_col8" class="data row0 col8" >2.25 sec</td>
#                         <td id="T_fca7b_row0_col9" class="data row0 col9" >45.27% (faster)</td>
#                         <td id="T_fca7b_row0_col10" class="data row0 col10" >1</td>
#             </tr>
#     </tbody></table>
